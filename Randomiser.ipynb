# %%
# At work as there are a few Data Engineers, we randomise who is going to give their update first at the daily stand up
# This code is work in progress but compromises of most of my Python learning so far which includes:
# Lists
# Indexing
# While loop
# if, elif, else


# Import the tkinter gui
from tkinter import *

# Import shuffle
from random import shuffle

# function
def addtolist():
    global List

    List = []
    for item in varList:
        if item.get() != "":
            List.append(item.get())
    print("Engineers Added\nClose Randomiser Window\nPress Enter to Reveal the First Engineer")

# main section

List = []
varList = []

myApp = Tk()
myApp.title("Randomiser")
myApp.geometry("300x500")

# Andy
# Explanation only for this block as all other 12 blocks are the same
# Variable assignment
engineer1 = StringVar()
# Checkbox assignment
cb1 = Checkbutton(myApp, text = "Andy", variable = engineer1,
                  # On and off values "" is user defined
                           onvalue = "Andy", offvalue = "")
# gui configuration
# row = the row within the gui
# column = the column within the gui. Notice the rows are set at increments to drag the gui down
# The increments could be set on the column to make the gui expand horizontally
# Sticky is the directon that you want the text, play around with E, SW, SE etc.
cb1.grid(row = 0, column = 1, sticky = W)

# Andrew C
engineer2 = StringVar()
cb2 = Checkbutton(myApp, text = "Andrew C", variable = engineer2,
                           onvalue = "Andrew C", offvalue = "")
cb2.grid(row = 1, column = 1, sticky = W)

# Iain
engineer3 = StringVar()
cb3 = Checkbutton(myApp, text = "Iain", variable = engineer3,
                           onvalue = "Iain", offvalue = "")
cb3.grid(row = 2, column = 1, sticky = W)

# Janet
engineer4 = StringVar()
cb4 = Checkbutton(myApp, text = "Janet", variable = engineer4,
                           onvalue = "Janet", offvalue = "")
cb4.grid(row = 3, column = 1, sticky = W)

# Lucy
engineer5 = StringVar()
cb5 = Checkbutton(myApp, text = "Lucy", variable = engineer5,
                           onvalue = "Lucy", offvalue = "")
cb5.grid(row = 4, column = 1, sticky = W)

# Mark B
engineer6 = StringVar()
cb6 = Checkbutton(myApp, text = "Mark B", variable = engineer6,
                           onvalue = "Mark B", offvalue = "")
cb6.grid(row = 5, column = 1, sticky = W)

# Mark H
engineer7 = StringVar()
cb7 = Checkbutton(myApp, text = "Mark H", variable = engineer7,
                           onvalue = "Mark H", offvalue = "")
cb7.grid(row = 6, column = 1, sticky = W)

# Matt
engineer8 = StringVar()
cb8 = Checkbutton(myApp, text = "Matt", variable = engineer8,
                           onvalue = "Matt", offvalue = "")
cb8.grid(row = 7, column = 1, sticky = W)

# Michael
engineer9 = StringVar()
cb9 = Checkbutton(myApp, text = "Michael", variable = engineer9,
                           onvalue = "Michael", offvalue = "")
cb9.grid(row = 8, column = 1, sticky = W)

# Naumaan
engineer10 = StringVar()
cb10 = Checkbutton(myApp, text = "Naumaan", variable = engineer10,
                           onvalue = "Naumaan", offvalue = "")
cb10.grid(row = 9, column = 1, sticky = W)

# Nick
engineer11 = StringVar()
cb11 = Checkbutton(myApp, text = "Nick", variable = engineer11,
                           onvalue = "Nick", offvalue = "")
cb11.grid(row = 10, column = 1, sticky = W)

# Piotr
engineer12 = StringVar()
cb12 = Checkbutton(myApp, text = "Piotr", variable = engineer12,
                           onvalue = "Piotr", offvalue = "")
cb12.grid(row = 11, column = 1, sticky = W)

# Rich
engineer13 = StringVar()
cb13 = Checkbutton(myApp, text = "Rich", variable = engineer13,
                           onvalue = "Rich", offvalue = "")
cb13.grid(row = 12, column = 1, sticky = W)

# Append Engineers
varList.append(engineer1)
varList.append(engineer2)
varList.append(engineer3)
varList.append(engineer4)
varList.append(engineer5)
varList.append(engineer6)
varList.append(engineer7)
varList.append(engineer8)
varList.append(engineer9)
varList.append(engineer10)
varList.append(engineer11)
varList.append(engineer12)
varList.append(engineer13)

# Create Add Button
b1 = Button(myApp, text = "Add", command = addtolist)
b1.grid(row = 15, column = 1)

mainloop()

# randomiser
# Place the hashtag symbol before any engineers who are not in attendance
engineers = List

# shuffle order of Engineers
shuffle(engineers)

max_engineers = len(engineers) 
eng = 0

# Iterating through Engineering Team using while loop 
while True:
    change_team = input("")
    
    if eng == 0:
        print(f'The first engineer is {engineers[eng]}')
        eng += 1
    elif eng > 0 and eng < max_engineers - 1:
        print(f'The next engineer is {engineers[eng]}')
        eng += 1
    else:
        print(f'Last but not least is {engineers[eng]}')
        break
