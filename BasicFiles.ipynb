# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second line
# this is the third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
pwd
# Out:
# 'C:\\Users\\ad_wi'

# %% [markdown]
# pwd provides the working notebook

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
myfile = open("E:\\Complete-Python-3-Bootcamp-master\\00-Python Object and Data Structure Basics\\test.txt")

# %%
myfile.readlines()
# Out:
# ['First Line\n', 'Second Line']

# %%
myfile.close()

# %%
myfile = open('myfile.txt')

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt',mode='r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Writing my_new_file.txt

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open('my_new_file.txt',mode='a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH

# %%
with open('dhdkhjhkjhk.txt',mode='w') as f:
    f.write('I CREATED THIS FILE!')

# %%
with open('dhdkhjhkjhk.txt',mode='r') as f:
    print(f.read())
# Out:
# I CREATED THIS FILE!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('test.txt',mode='w') as f:
    f.write('Hello World')
    f.close()

# %%
myfile = open('test.txt')

# %%
myfile.read()
# Out:
# 'Hello World'

# %%
myfile.close()
